# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from statsmodels.tsa.arima.model import ARIMA

# %%
with open("pipeline_preprocessing.pkl", "rb") as file:
    pipeline_preprocessing  = pickle.load(file )

# %%
df_train = pd.read_csv('data/train.csv')

# %%
df_train.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
X = df_train
y = df_train.sales

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3)

# %%
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 3000883            0
# 3000884            1
# 3000885          148
# 3000886            8
# 3000887            0
#
# [3000888 rows x 6 columns]

# %% [markdown]
# # baseline model : simple linear regression

# %%
pipe_linear = Pipeline([
    ('pipeline_preprocessing', pipeline_preprocessing),
    ('linear_regression', LinearRegression())
], 
    verbose=False)

# %%
pipe_linear.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('pipeline_preprocessing',
#                  Pipeline(steps=[('transformer_preprocessing',
#                                   ColumnTransformer(transformers=[('preprocessing_tranformer',
#                                                                    PreprocessingTranformer(),
#                                                                    ['date']),
#                                                                   ('one_hot_encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False),
#                                                                    ['family'])])),
#                                  ('standard_scaler', StandardScaler())])),
#                 ('linear_regression', LinearRegression())])

# %%
y_pred = pipe_linear.predict(X_val)
y_pred_positives = np.amax(np.vstack((y_pred, np.zeros(y_pred.size))),0)

# %%
rmsle = np.sqrt(mean_squared_log_error(y_val, y_pred_positives))
print(f"RMSLE : {rmsle:.2f}")
# Out:
# RMSLE : 2.40

# %% [markdown]
# # ARMA Model

# %%
X_train_proc = pd.DataFrame(
    pipeline_preprocessing.fit_transform(X_train), 
    columns=pipeline_preprocessing['transformer_preprocessing'].get_feature_names_out()
)

# %%
X_train_proc
# Out:
#          preprocessing_tranformer__year  preprocessing_tranformer__sin_month  \
# 0                             -0.622903                             1.356491
# 1                              0.863126                            -1.486979
# 2                              1.606141                            -0.065244
# 3                             -0.622903                             1.166015
# 4                              1.606141                            -0.065244
# ...                                 ...                                  ...
# 2100616                       -0.622903                            -0.065244
# 2100617                       -0.622903                            -0.065244
# 2100618                        0.863126                            -0.776112
# 2100619                       -0.622903                             1.166015
# 2100620                       -0.622903                            -1.296503
#
#          preprocessing_tranformer__cos_month  \
# 0                                   0.060327
# 1                                   0.060327
# 2                                  -1.351987
# 3                                  -0.645830
# 4                                  -1.351987
# ...                                      ...
# 2100616                             1.472641
# 2100617                             1.472641
# 2100618                             1.283426
# 2100619                             0.766484
# 2100620                             0.766484
#
#          preprocessing_tranformer__sin_day_of_week  \
# 0                                        -1.323361
# 1                                         1.321193
# 2                                        -1.323361
# 3                                        -0.001084
# 4                                        -1.323361
# ...                                            ...
# 2100616                                   1.321193
# 2100617                                   1.321193
# 2100618                                   1.321193
# 2100619                                  -0.001084
# 2100620                                  -0.001084
#
#          preprocessing_tranformer__cos_day_of_week  \
# 0                                        -0.868793
# 1                                        -0.868793
# 2                                        -0.868793
# 3                                         1.153472
# 4                                        -0.868793
# ...                                            ...
# 2100616                                  -0.868793
# 2100617                                  -0.868793
# 2100618                                   0.479384
# 2100619                                  -1.542881
# 2100620                                   1.153472
#
#          one_hot_encoder__family_AUTOMOTIVE  \
# 0                                 -0.176825
# 1                                 -0.176825
# 2                                 -0.176825
# 3                                 -0.176825
# 4                                 -0.176825
# ...                                     ...
# 2100616                           -0.176825
# 2100617                           -0.176825
# 2100618                           -0.176825
# 2100619                           -0.176825
# 2100620                           -0.176825
#
#          one_hot_encoder__family_BABY CARE  one_hot_encoder__family_BEAUTY  \
# 0                                -0.176844                       -0.176751
# 1                                -0.176844                       -0.176751
# 2                                 5.654710                       -0.176751
# 3                                -0.176844                       -0.176751
# 4                                -0.176844                       -0.176751
# ...                                    ...                             ...
# 2100616                          -0.176844                       -0.176751
# 2100617                          -0.176844                       -0.176751
# 2100618                          -0.176844                       -0.176751
# 2100619                          -0.176844                       -0.176751
# 2100620                          -0.176844                       -0.176751
#
#          one_hot_encoder__family_BEVERAGES  one_hot_encoder__family_BOOKS  \
# 0                                -0.176551                      -0.176907
# 1                                -0.176551                      -0.176907
# 2                                -0.176551                      -0.176907
# 3                                 5.664070                      -0.176907
# 4                                -0.176551                      -0.176907
# ...                                    ...                            ...
# 2100616                          -0.176551                      -0.176907
# 2100617                          -0.176551                      -0.176907
# 2100618                          -0.176551                      -0.176907
# 2100619                          -0.176551                      -0.176907
# 2100620                          -0.176551                      -0.176907
#
#          ...  one_hot_encoder__family_MAGAZINES  \
# 0        ...                          -0.176781
# 1        ...                          -0.176781
# 2        ...                          -0.176781
# 3        ...                          -0.176781
# 4        ...                          -0.176781
# ...      ...                                ...
# 2100616  ...                           5.656725
# 2100617  ...                          -0.176781
# 2100618  ...                          -0.176781
# 2100619  ...                          -0.176781
# 2100620  ...                          -0.176781
#
#          one_hot_encoder__family_MEATS  one_hot_encoder__family_PERSONAL CARE  \
# 0                            -0.176695                              -0.176802
# 1                            -0.176695                               5.656038
# 2                            -0.176695                              -0.176802
# 3                            -0.176695                              -0.176802
# 4                            -0.176695                              -0.176802
# ...                                ...                                    ...
# 2100616                      -0.176695                              -0.176802
# 2100617                      -0.176695                              -0.176802
# 2100618                      -0.176695                              -0.176802
# 2100619                      -0.176695                              -0.176802
# 2100620                      -0.176695                              -0.176802
#
#          one_hot_encoder__family_PET SUPPLIES  \
# 0                                   -0.176701
# 1                                   -0.176701
# 2                                   -0.176701
# 3                                   -0.176701
# 4                                   -0.176701
# ...                                       ...
# 2100616                             -0.176701
# 2100617                             -0.176701
# 2100618                             -0.176701
# 2100619                             -0.176701
# 2100620                             -0.176701
#
#          one_hot_encoder__family_PLAYERS AND ELECTRONICS  \
# 0                                              -0.176541
# 1                                              -0.176541
# 2                                              -0.176541
# 3                                              -0.176541
# 4                                               5.664392
# ...                                                  ...
# 2100616                                        -0.176541
# 2100617                                        -0.176541
# 2100618                                        -0.176541
# 2100619                                        -0.176541
# 2100620                                        -0.176541
#
#          one_hot_encoder__family_POULTRY  \
# 0                              -0.176642
# 1                              -0.176642
# 2                              -0.176642
# 3                              -0.176642
# 4                              -0.176642
# ...                                  ...
# 2100616                        -0.176642
# 2100617                        -0.176642
# 2100618                        -0.176642
# 2100619                        -0.176642
# 2100620                        -0.176642
#
#          one_hot_encoder__family_PREPARED FOODS  \
# 0                                     -0.177098
# 1                                     -0.177098
# 2                                     -0.177098
# 3                                     -0.177098
# 4                                     -0.177098
# ...                                         ...
# 2100616                               -0.177098
# 2100617                               -0.177098
# 2100618                                5.646580
# 2100619                               -0.177098
# 2100620                               -0.177098
#
#          one_hot_encoder__family_PRODUCE  \
# 0                              -0.176915
# 1                              -0.176915
# 2                              -0.176915
# 3                              -0.176915
# 4                              -0.176915
# ...                                  ...
# 2100616                        -0.176915
# 2100617                        -0.176915
# 2100618                        -0.176915
# 2100619                         5.652423
# 2100620                        -0.176915
#
#          one_hot_encoder__family_SCHOOL AND OFFICE SUPPLIES  \
# 0                                                -0.177037
# 1                                                -0.177037
# 2                                                -0.177037
# 3                                                -0.177037
# 4                                                -0.177037
# ...                                                    ...
# 2100616                                          -0.177037
# 2100617                                          -0.177037
# 2100618                                          -0.177037
# 2100619                                          -0.177037
# 2100620                                          -0.177037
#
#          one_hot_encoder__family_SEAFOOD
# 0                              -0.176782
# 1                              -0.176782
# 2                              -0.176782
# 3                              -0.176782
# 4                              -0.176782
# ...                                  ...
# 2100616                        -0.176782
# 2100617                        -0.176782
# 2100618                        -0.176782
# 2100619                        -0.176782
# 2100620                        -0.176782
#
# [2100621 rows x 38 columns]

# %%
arma_model = ARIMA(X_train_proc, freq='D', order=(6,0,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t2/11r8pzzd1yv36w3wwl6xvjqm0000gn/T/ipykernel_11118/134125620.py in <module>
# ----> 1 arma_model = ARIMA(X_train_proc, freq='D', order=(6,0,1))
#
# /opt/homebrew/Cellar/jupyterlab/3.2.5/libexec/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py in __init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     151         # this criteria. Instead, we'll just make sure that the parameter
#     152         # estimates from those methods satisfy the criteria.)
# --> 153         self._spec_arima = SARIMAXSpecification(
#     154             endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     155             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#
# /opt/homebrew/Cellar/jupyterlab/3.2.5/libexec/lib/python3.9/site-packages/statsmodels/tsa/arima/specification.py in __init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     444         # especially validating shapes, retrieving names, and potentially
#     445         # providing us with a time series index
# --> 446         self._model = TimeSeriesModel(endog, exog=exog, dates=dates, freq=freq,
#     447                                       missing=missing)
#     448         self.endog = None if faux_endog else self._model.endog
#
# /opt/homebrew/Cellar/jupyterlab/3.2.5/libexec/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py in __init__(self, endog, exog, dates, freq, missing, **kwargs)
#     426
#     427         # Date handling in indexes
# --> 428         self._init_dates(dates, freq)
#     429
#     430     def _init_dates(self, dates=None, freq=None):
#
# /opt/homebrew/Cellar/jupyterlab/3.2.5/libexec/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py in _init_dates(self, dates, freq)
#     477         # Sanity check that we do not have a `freq` without an index
#     478         if index is None and freq is not None:
# --> 479             raise ValueError('Frequency provided without associated index.')
#     480
#     481         # If an index is available, see if it is a date-based index or if it
#
# ValueError: Frequency provided without associated index.

# %%
df_test = pd.read_csv('data/test.csv')

# %%
df_test_proc = pd.DataFrame(
    pipeline_preprocessing.fit_transform(df_test), 
    columns=pipeline_preprocessing['transformer_preprocessing'].get_feature_names_out()
)

df_test_proc.head()
# Out:
#    preprocessing_tranformer__year  preprocessing_tranformer__sin_month  \
# 0                             0.0                         3.232969e-13
# 1                             0.0                         3.232969e-13
# 2                             0.0                         3.232969e-13
# 3                             0.0                         3.232969e-13
# 4                             0.0                         3.232969e-13
#
#    preprocessing_tranformer__cos_month  \
# 0                        -3.330669e-16
# 1                        -3.330669e-16
# 2                        -3.330669e-16
# 3                        -3.330669e-16
# 4                        -3.330669e-16
#
#    preprocessing_tranformer__sin_day_of_week  \
# 0                                   1.254363
# 1                                   1.254363
# 2                                   1.254363
# 3                                   1.254363
# 4                                   1.254363
#
#    preprocessing_tranformer__cos_day_of_week  \
# 0                                  -0.699287
# 1                                  -0.699287
# 2                                  -0.699287
# 3                                  -0.699287
# 4                                  -0.699287
#
#    one_hot_encoder__family_AUTOMOTIVE  one_hot_encoder__family_BABY CARE  \
# 0                            5.656854                          -0.176777
# 1                           -0.176777                           5.656854
# 2                           -0.176777                          -0.176777
# 3                           -0.176777                          -0.176777
# 4                           -0.176777                          -0.176777
#
#    one_hot_encoder__family_BEAUTY  one_hot_encoder__family_BEVERAGES  \
# 0                       -0.176777                          -0.176777
# 1                       -0.176777                          -0.176777
# 2                        5.656854                          -0.176777
# 3                       -0.176777                           5.656854
# 4                       -0.176777                          -0.176777
#
#    one_hot_encoder__family_BOOKS  ...  one_hot_encoder__family_MAGAZINES  \
# 0                      -0.176777  ...                          -0.176777
# 1                      -0.176777  ...                          -0.176777
# 2                      -0.176777  ...                          -0.176777
# 3                      -0.176777  ...                          -0.176777
# 4                       5.656854  ...                          -0.176777
#
#    one_hot_encoder__family_MEATS  one_hot_encoder__family_PERSONAL CARE  \
# 0                      -0.176777                              -0.176777
# 1                      -0.176777                              -0.176777
# 2                      -0.176777                              -0.176777
# 3                      -0.176777                              -0.176777
# 4                      -0.176777                              -0.176777
#
#    one_hot_encoder__family_PET SUPPLIES  \
# 0                             -0.176777
# 1                             -0.176777
# 2                             -0.176777
# 3                             -0.176777
# 4                             -0.176777
#
#    one_hot_encoder__family_PLAYERS AND ELECTRONICS  \
# 0                                        -0.176777
# 1                                        -0.176777
# 2                                        -0.176777
# 3                                        -0.176777
# 4                                        -0.176777
#
#    one_hot_encoder__family_POULTRY  one_hot_encoder__family_PREPARED FOODS  \
# 0                        -0.176777                               -0.176777
# 1                        -0.176777                               -0.176777
# 2                        -0.176777                               -0.176777
# 3                        -0.176777                               -0.176777
# 4                        -0.176777                               -0.176777
#
#    one_hot_encoder__family_PRODUCE  \
# 0                        -0.176777
# 1                        -0.176777
# 2                        -0.176777
# 3                        -0.176777
# 4                        -0.176777
#
#    one_hot_encoder__family_SCHOOL AND OFFICE SUPPLIES  \
# 0                                          -0.176777
# 1                                          -0.176777
# 2                                          -0.176777
# 3                                          -0.176777
# 4                                          -0.176777
#
#    one_hot_encoder__family_SEAFOOD
# 0                        -0.176777
# 1                        -0.176777
# 2                        -0.176777
# 3                        -0.176777
# 4                        -0.176777
#
# [5 rows x 38 columns]
